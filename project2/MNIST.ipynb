# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the Data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = tf.keras.utils.normalize(x_train, axis = 1)
x_test = tf.keras.utils.normalize(x_test, axis = 1)

# %% [markdown]
# # Look at an image

# %%
plt.imshow(x_train[0], cmap = 'gray')

# %% [markdown]
# # Build your model:
#
# model = *code to create tensorflow Sequential model*
#
# model.add( layers.Dense() )
#   - Specify how many neurons, and activation function. ex( model.Dense(3, activation = 'sigmoid') )
#
# model.add( layers.Flatten() )
#   - Flattens the image into one flat line
#
# After the model is created, you can do model.compile()
#   - Specify loss function, and optimizer
#   - ex. model.compile( loss = 'sparse_categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'] )

# %%
#define your model here. ie, "model = <tensorflow syntax for sequential model>"
model = tf.keras.models.Sequential()

# %%
#create your model here
model.add(layers.Flatten())
model.add(layers.Dense(128, activation = tf.nn.relu))
model.add(layers.Dense(128, activation = tf.nn.relu))
model.add(layers.Dense(10, activation = tf.nn.softmax))
model.compile(loss = "sparse_categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])
model.fit(x_train, y_train, epochs = 3)
# Out:
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8694 - loss: 0.4741
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9649 - loss: 0.1120
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9778 - loss: 0.0704

# %% [markdown]
# View your model in action

# %%
number_of_images = 5

probabilities = model.predict(x_test[:number_of_images])
predictions = np.argmax(probabilities, axis=1)
for index in range(len(probabilities)):
  plt.imshow(x_test[index], cmap='gray')
  plt.show()
  print("Prediction: ", predictions[index])
# Out:
# WARNING:tensorflow:5 out of the last 317 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78ebf88916c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Prediction:  7
# Prediction:  2
# Prediction:  1
# Prediction:  0
# Prediction:  4

# %% [markdown]
# Look at incorrect predictions:

# %%
#code here
probabilities = model.predict(x_test)
predictions = np.argmax(probabilities, axis=1)
for index in range(len(probabilities)):
  if y_test[index] != predictions[index]:
    plt.imshow(x_test[index], cmap='gray')
    plt.show()
    print("Prediction: ", predictions[index])
# Out:
# WARNING:tensorflow:6 out of the last 318 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78ebf88916c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Prediction:  8
# Prediction:  5
# Prediction:  5
# Prediction:  2
# Prediction:  0
# Prediction:  7
# Prediction:  3
# Prediction:  7
# Prediction:  8
# Prediction:  0
# Prediction:  2
# Prediction:  2
# Prediction:  8
# Prediction:  3
# Prediction:  6
# Prediction:  8
# Prediction:  8
# Prediction:  3
# Prediction:  4
# Prediction:  8
# Prediction:  9
# Prediction:  9
# Prediction:  8
# Prediction:  7
# Prediction:  7
# Prediction:  9
# Prediction:  7
# Prediction:  2
# Prediction:  0
# Prediction:  5
# Prediction:  2
# Prediction:  8
# Prediction:  6
# Prediction:  7
# Prediction:  0
# Prediction:  1
# Prediction:  8
# Prediction:  8
# Prediction:  2
# Prediction:  4
# Prediction:  9
# Prediction:  5
# Prediction:  3
# Prediction:  8
# Prediction:  6
# Prediction:  3
# Prediction:  0
# Prediction:  8
# Prediction:  9
# Prediction:  3
# Prediction:  7
# Prediction:  6
# Prediction:  3
# Prediction:  3
# Prediction:  3
# Prediction:  3
# Prediction:  7
# Prediction:  3
# Prediction:  0
# Prediction:  9
# Prediction:  2
# Prediction:  2
# Prediction:  8
# Prediction:  3
# Prediction:  4
# Prediction:  2
# Prediction:  3
# Prediction:  0
# Prediction:  9
# Prediction:  9
# Prediction:  2
# Prediction:  8
# Prediction:  0
# Prediction:  1
# Prediction:  0
# Prediction:  7
# Prediction:  9
# Prediction:  1
# Prediction:  8
# Prediction:  3
# Prediction:  8
# Prediction:  0
# Prediction:  3
# Prediction:  0
# Prediction:  8
# Prediction:  1
# Prediction:  3
# Prediction:  1
# Prediction:  4
# Prediction:  4
# Prediction:  8
# Prediction:  4
# Prediction:  3
# Prediction:  7
# Prediction:  0
# Prediction:  1
# Prediction:  8
# Prediction:  4
# Prediction:  4
# Prediction:  8
# Prediction:  4
# Prediction:  9
# Prediction:  5
# Prediction:  3
# Prediction:  2
# Prediction:  2
# Prediction:  7
# Prediction:  8
# Prediction:  1
# Prediction:  8
# Prediction:  2
# Prediction:  3
# Prediction:  9
# Prediction:  0
# Prediction:  1
# Prediction:  4
# Prediction:  9
# Prediction:  0
# Prediction:  5
# Prediction:  3
# Prediction:  0
# Prediction:  9
# Prediction:  3
# Prediction:  8
# Prediction:  2
# Prediction:  3
# Prediction:  6
# Prediction:  8
# Prediction:  8
# Prediction:  3
# Prediction:  3
# Prediction:  4
# Prediction:  1
# Prediction:  4
# Prediction:  3
# Prediction:  3
# Prediction:  3
# Prediction:  6
# Prediction:  3
# Prediction:  3
# Prediction:  4
# Prediction:  3
# Prediction:  4
# Prediction:  4
# Prediction:  8
# Prediction:  8
# Prediction:  3
# Prediction:  4
# Prediction:  3
# Prediction:  5
# Prediction:  6
# Prediction:  9
# Prediction:  1
# Prediction:  7
# Prediction:  8
# Prediction:  3
# Prediction:  8
# Prediction:  7
# Prediction:  7
# Prediction:  3
# Prediction:  3
# Prediction:  4
# Prediction:  4
# Prediction:  2
# Prediction:  7
# Prediction:  1
# Prediction:  5
# Prediction:  4
# Prediction:  4
# Prediction:  3
# Prediction:  8
# Prediction:  3
# Prediction:  4
# Prediction:  4
# Prediction:  8
# Prediction:  3
# Prediction:  3
# Prediction:  4
# Prediction:  3
# Prediction:  6
# Prediction:  8
# Prediction:  8
# Prediction:  9
# Prediction:  8
# Prediction:  9
# Prediction:  2
# Prediction:  7
# Prediction:  6
# Prediction:  4
# Prediction:  0
# Prediction:  0
# Prediction:  3
# Prediction:  3
# Prediction:  8
# Prediction:  8
# Prediction:  3
# Prediction:  3
# Prediction:  0
# Prediction:  5
# Prediction:  3
# Prediction:  8
# Prediction:  3
# Prediction:  3
# Prediction:  0
# Prediction:  9
# Prediction:  8
# Prediction:  4
# Prediction:  6
# Prediction:  7
# Prediction:  4
# Prediction:  5
# Prediction:  9
# Prediction:  6
# Prediction:  4
# Prediction:  6
# Prediction:  3
# Prediction:  8
# Prediction:  8
# Prediction:  2
# Prediction:  8
# Prediction:  8
# Prediction:  6
# Prediction:  8
# Prediction:  8
# Prediction:  8
# Prediction:  8
# Prediction:  8
# Prediction:  4
# Prediction:  6
# Prediction:  3
# Prediction:  8
# Prediction:  8
# Prediction:  3
# Prediction:  8
# Prediction:  2
# Prediction:  2
# Prediction:  2
# Prediction:  2
# Prediction:  8
# Prediction:  8
# Prediction:  9
# Prediction:  5
# Prediction:  3
# Prediction:  4
# Prediction:  8
# Prediction:  7
# Prediction:  7
# Prediction:  3
# Prediction:  7
# Prediction:  8
# Prediction:  3
# Prediction:  3
# Prediction:  6
# Prediction:  0
# Prediction:  6
# Prediction:  0
# Prediction:  0
# Prediction:  0
# Prediction:  0
# Prediction:  7
# Prediction:  8
# Prediction:  3
# Prediction:  8
# Prediction:  0
# Prediction:  3
# Prediction:  8
# Prediction:  3
# Prediction:  6
